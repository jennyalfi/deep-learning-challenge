# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application = application_df['APPLICATION_TYPE'].value_counts()
print(application)
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

application_types_to_replace = application[application < 500].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification = application_df['CLASSIFICATION'].value_counts()
classification
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
# classification = application_df['CLASSIFICATION'].value_counts()

classification[classification > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = classification[classification < 1800].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
categorical_dummies = ['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION',
                        'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS']

application_df_encoded = pd.get_dummies(application_df, columns = categorical_dummies)

application_df_encoded.head().shape[1]
# Out:
# 44

# %%
# Split our preprocessed data into our features and target arrays
y = application_df_encoded["IS_SUCCESSFUL"].values
X = application_df_encoded.drop(["IS_SUCCESSFUL"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# <ipython-input-10-16bfb24d7023>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = application_df_encoded.drop(["IS_SUCCESSFUL"],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  132
hidden_nodes_layer2 = 66

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 132)               5808
#
#  dense_1 (Dense)             (None, 66)                8778
#
#  dense_2 (Dense)             (None, 1)                 67
#
# =================================================================
# Total params: 14,653
# Trainable params: 14,653
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5704 - accuracy: 0.7201
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5573 - accuracy: 0.7297
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5532 - accuracy: 0.7317
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5512 - accuracy: 0.7327
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5497 - accuracy: 0.7328
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5488 - accuracy: 0.7329
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5479 - accuracy: 0.7331
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5469 - accuracy: 0.7353
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5465 - accuracy: 0.7362
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5465 - accuracy: 0.7355
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5459 - accuracy: 0.7348
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5452 - accuracy: 0.7350
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5445 - accuracy: 0.7376
# Epoch 14/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5439 - accuracy: 0.7368
# Epoch 15/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5437 - accuracy: 0.7373
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5439 - accuracy: 0.7369
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5434 - accuracy: 0.7377
# Epoch 18/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5426 - accuracy: 0.7373
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5420 - accuracy: 0.7380
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5423 - accuracy: 0.7378
# Epoch 21/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5425 - accuracy: 0.7386
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5423 - accuracy: 0.7385
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5416 - accuracy: 0.7387
# Epoch 24/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5415 - accuracy: 0.7389
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5411 - accuracy: 0.7392
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5409 - accuracy: 0.7386
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5402 - accuracy: 0.7392
# Epoch 28/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5405 - accuracy: 0.7397
# Epoch 29/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5408 - accuracy: 0.7384
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5398 - accuracy: 0.7384
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5397 - accuracy: 0.7395
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7396
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7388
# Epoch 34/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5401 - accuracy: 0.7391
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5394 - accuracy: 0.7391
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5396 - accuracy: 0.7397
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5394 - accuracy: 0.7399
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5397 - accuracy: 0.7395
# Epoch 39/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7395
# Epoch 40/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7391
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7396
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.7401
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7396
# Epoch 44/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5382 - accuracy: 0.7399
# Epoch 45/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5385 - accuracy: 0.7406
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5381 - accuracy: 0.7403
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7399
# Epoch 48/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.7402
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7405
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5378 - accuracy: 0.7400
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.7400
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.7404
# Epoch 53/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7403
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5377 - accuracy: 0.7403
# Epoch 55/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.7400
# Epoch 56/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7404
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7407
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7407
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5371 - accuracy: 0.7404
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5364 - accuracy: 0.7409
# Epoch 61/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7403
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7411
# Epoch 63/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.7409
# Epoch 64/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7418
# Epoch 65/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7409
# Epoch 66/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7412
# Epoch 67/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7410
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7407
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7410
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7413
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5359 - accuracy: 0.7413
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5360 - accuracy: 0.7412
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5357 - accuracy: 0.7412
# Epoch 74/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5357 - accuracy: 0.7417
# Epoch 75/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5356 - accuracy: 0.7411
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5358 - accuracy: 0.7414
# Epoch 77/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7409
# Epoch 78/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7411
# Epoch 79/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7411
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7409
# Epoch 81/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5352 - accuracy: 0.7413
# Epoch 82/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5356 - accuracy: 0.7412
# Epoch 83/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5352 - accuracy: 0.7414
# Epoch 84/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.7409
# Epoch 85/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7411
# Epoch 86/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7413
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7409
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.7416
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7414
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7413
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7410
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5352 - accuracy: 0.7410
# Epoch 93/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5345 - accuracy: 0.7416
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5342 - accuracy: 0.7415
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7414
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7413
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7418
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.7416
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7413
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5340 - accuracy: 0.7418

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5621 - accuracy: 0.7264 - 351ms/epoch - 1ms/step
# Loss: 0.5621320605278015, Accuracy: 0.7264139652252197

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization1.h5")

# %% [markdown]
# # New Section
